# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df=pd.read_csv('tips.csv')

# %%
# 회귀분석
sns.regplot(x='total_bill',y='tip',data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# hue: class
sns.displot(data=df,x='smoker',hue='smoker')

# %%
# hue: class
sns.displot(data=df,x='sex',hue='sex')

# %%
# hue: class cataorical
sns.displot(data=df,x='tip',hue='tip')

# %%
# hue: class cataorical
sns.displot(data=df,x='day',hue='day')

# %%
# 산점도
sns.scatterplot(x='total_bill', y='tip', hue='sex',data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins.groupby('species').count()
# Out:
#            island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species
# Adelie        152             151            151                151
# Chinstrap      68              68             68                 68
# Gentoo        124             123            123                123
#
#            body_mass_g  sex
# species
# Adelie             151  146
# Chinstrap           68   68
# Gentoo             123  119

# %%
sns.scatterplot(x='flipper_length_mm', y='island', 
                hue='sex',data=penguins)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='island'>

# %%
sns.scatterplot(x='flipper_length_mm', y='body_mass_g', 
                hue='sex',data=penguins)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.histplot(data=penguins, x="flipper_length_mm", 
             hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
# 연속된 그래프
sns.kdeplot(data=penguins, x="flipper_length_mm", 
            hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.displot(data=penguins, x="flipper_length_mm", 
            hue="species", multiple="stack")

# %%
sns.displot(data=penguins, x="flipper_length_mm", 
            hue="species", col="species")
