# %% [markdown]
# ### Statiz
# 필요한 정보: 선수 이름 생일
# 주소 http://www.statiz.co.kr/player.php?opt=1&sopt=0&name=%EA%B0%95%EB%AF%BC%ED%98%B8&birth=1985-08-18&re=2&se=0&da=1 <br>
# 종합 opt=0 연도별 opt=1 <br>
# sopt는 디폴트 인 듯 <br>
# name=이름(지금은 강민호) <br>
# birth=yyyy-mm-dd 형식 <br>
# 타자 re=0 투수 re=1 수비 re=2 <br>
# 졍규 se=0 포스트시즌 se=1 <br>
# 타자 투수는 da = 1 to 14 <br>
# 수비는 da = 1 to 4

# %%
import os
webdriver_path = os.getcwd()+'\\webdriver\\chromedriver.exe'

# %%
from selenium import webdriver 
import time 
import pandas as pd

# %%
url = 'http://www.statiz.co.kr/main.php' 
driver = webdriver.Chrome(webdriver_path) 
driver.get(url)
# Out:
# <ipython-input-3-4af1f2a6752c>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(webdriver_path)

# %%
keyword = ['강민호']
driver.find_element_by_id('search_text').send_keys(keyword)
# Out:
# C:\Users\SEC\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:390: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")

# %%
# xpath = '//*[@id="search-btn"]'
# driver.find_element_by_xpath(xpath).click()

driver.find_element_by_css_selector('#search-btn > i').click()

# %%
yearly_xpath='/html/body/div/div[1]/div/section[2]/div/div[1]/div/div[3]/div/div[2]/table/tbody/tr/td/a[2]'
driver.find_element_by_xpath(yearly_xpath).click()
# Out:
# C:\Users\SEC\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:670: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")

# %%
xpath='/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[2]/div[1]/a[1]'
driver.find_element_by_xpath(xpath).click()
# Out:
# C:\Users\SEC\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:430: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")

# %%
driver.find_element_by_tag_name('table')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="8fb39b48662eed41adf8cbf61ca8b3d9", element="9925de67-0481-47ee-8b97-8975b145e8f1")>

# %%
driver.close()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-28-ad0c9a213c39> in <module>
# ----> 1 driver.close()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in close(self)
#     772                 driver.close()
#     773         """
# --> 774         self.execute(Command.CLOSE)
#     775
#     776     def quit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     345         response = self.command_executor.execute(driver_command, params)
#     346         if response:
# --> 347             self.error_handler.check_response(response)
#     348             response['value'] = self._unwrap_value(
#     349                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
# ...

# %%
/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[2]/div[1]/a[1]
/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[2]/div[1]/a[2]
/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[2]/div[1]/a[3]

# %%
import pandas as pd 
import requests 
from bs4 import BeautifulSoup as bs 

url_base = 'https://www.koreabaseball.com/Record/Player/{category}' 
category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 'Defense/Basic.aspx', 'Runner/Basic.aspx'] 

data_list = []
for category in category_list: 
    url = url_base.format(category = category)
    req = requests.get(url)

    html = req.text
    soup = bs(html,'html.parser')

    temp_table = soup.find('div', {'class':'record_result'})

    col_tag = temp_table.find_all('td') 
    
    col_list = ['Rank', 'Name', 'Team']

# %%
import pandas as pd 
import requests 
from bs4 import BeautifulSoup as bs 

url = 'http://www.statiz.co.kr/player.php?opt=1&sopt=0&name=%EA%B0%95%EB%AF%BC%ED%98%B8&birth=1985-08-18&re=0&se=0&da=1'

req = requests.get(url)

html = req.text

soup = bs(html,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>STATIZ</title>
# <!-- Tell the browser to be responsive to screen width -->
# <!-- meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport" -->
# <!-- Bootstrap 3.3.5 -->
# <link href="bootstrap/css/bootstrap.min.css" rel="stylesheet"/>
# <!-- Font Awesome -->
# <!--<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">-->
# <!--<link rel="stylesheet" href="https://cdn.jsdelivr.net/fontawesome/4.7.0/css/font-awesome.min.css">-->
# <link href="css/font-awesome-4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
# <!-- Ionicons -->
# <link href="https://code.ionicframework.com/ionicons/2.0.1/css/ionicons.min.css" rel="stylesheet"/>
# <!-- Theme style -->
# <link href="dist/css/AdminLTE.min.css" rel="stylesheet"/>
# <!-- AdminLTE Skins. Choose a skin from the css/skins
# ...

# %%
temp_table = soup.find('div', {'class':'box-body no-padding table-responsive'})
temp_table
# Out:
# <div class="box-body no-padding table-responsive">
# <table class="table table-striped table-responsive table-condensed no-space table-bordered" style="font-size:;">
# ...

# %%
<div class="box-body no-padding table-responsive">

                        <table class="table table-striped table-responsive  table-condensed no-space table-bordered" style="font-size:;">
<tbody><tr class="colhead_stz0"><th style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;" rowspan="2"><span style="padding-left:3px;padding-right:3px;">연도</span></th><th style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;" rowspan="2"><span style="padding-left:3px;padding-right:3px;">팀</span></th><th style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;" rowspan="2"><span style="padding-left:3px;padding-right:3px;">나이</span></th><th rowspan="2" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;"><span style="padding-left:3px;padding-right:3px;">P</span></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;경기&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">G</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;타석&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">타<br>석</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;타수&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">타<br>수</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;득점&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">득<br>점</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;안타&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">안<br>타</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;2루타&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">2<br>타</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;3루타&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">3<br>타</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;홈런&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">홈<br>런</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;루타수 (단타 + 2루타*2 + 3루타*3 + 홈런*4)&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">루<br>타</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;타점&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">타<br>점</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;도루&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">도<br>루</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;도루 실패&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">도<br>실</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;볼넷&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">볼<br>넷</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;몸에 맞는 볼&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">사<br>구</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;고의 4구&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">고<br>4</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;삼진&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">삼<br>진</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;병살타&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">병<br>살</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;희생번트&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">희<br>타</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;희생플라이&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">희<br>비</div></th><th rowspan="1" colspan="6" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;border-left:2px solid #333333;" onmouseover="ExpSet(&quot;타율 (안타/타수)&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">비율</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;border-left:2px solid #333333;" onmouseover="ExpSet(&quot;대체 선수 대비 승리 기여 (수비 RAA 제외)&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">WAR*</div></th><th colspan="1" rowspan="2" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;"><span style="color:#999999;padding-left:3px;padding-right:3px;">WPA</span></th></tr><tr class="colhead_stz0"><th rowspan="1" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;border-left:2px solid #333333;" onmouseover="ExpSet(&quot;타율 (안타/타수)&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">타율</div></th><th rowspan="1" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;출루율 ((안타+볼넷+몸에맞는볼)/(타수+볼넷+몸에맞는볼+희생플라이))&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">출루</div></th><th rowspan="1" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;장타율 (총루타수/타수)&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">장타</div></th><th rowspan="1" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;OPS (출루율+장타율)&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">OPS</div></th><th rowspan="1" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;Weighted On Base Average,  (0.72*고4제외4구+0.75*사구+0.90*단타+0.92*실출+1.24*2타+1.56*3타+1.95*홈런)/(타석-고4), 출루율 스케일&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">wOBA</div></th><th rowspan="1" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;조정 wRC, (((파크팩터를_적용한_wRAA /타석)/(리그득점/리그타석))+1)*100, OPS+ 스케일&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">wRC+</div></th></tr><tr><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="colhead_stz"><span style="padding-left:3px;padding-right:3px;">2004</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center"><span style="padding-left:3px;padding-right:3px;">롯데</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center"><span style="padding-left:3px;padding-right:3px;">19</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="statdata"><span style="padding-left:3px;padding-right:3px;">C</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">3</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">6</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">5</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">3</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">1</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;border-left:2px solid #333333;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.000</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.000</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.000</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.000</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.000</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">-133.3</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;border-left:2px solid #333333;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">-0.13</span></font></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;"></td></tr><tr><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="colhead_stz"><span style="padding-left:3px;padding-right:3px;">2005</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center"><span style="padding-left:3px;padding-right:3px;">롯데</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center"><span style="padding-left:3px;padding-right:3px;">20</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="statdata"><span style="padding-left:3px;padding-right:3px;">C</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">104</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">230</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">214</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">20</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">52</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">11</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">2</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">2</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">73</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">18</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">1</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">4</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">5</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">2</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">56</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">7</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">9</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;border-left:2px solid #333333;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.243</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.267</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.341</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.608</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.269</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">54.6</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;border-left:2px solid #333333;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.21</span></font></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;"></td></tr><tr><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="colhead_stz"><span style="padding-left:3px;padding-right:3px;">2006</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center"><span style="padding-left:3px;padding-right:3px;">롯데</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center"><span style="padding-left:3px;padding-right:3px;">21</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="statdata"><span style="padding-left:3px;padding-right:3px;">C</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">126</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">460</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">410</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">40</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">103</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">20</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">9</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">150</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">53</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">4</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">1</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">23</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">11</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">2</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">78</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">5</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">14</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">2</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;border-left:2px solid #333333;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.251</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.307</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.366</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.673</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.305</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">89.4</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;border-left:2px solid #333333;" class="statdata"><span style="padding-left:3px;padding-right:3px;">2.63</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;"></td></tr><tr><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="colhead_stz"><span style="padding-left:3px;padding-right:3px;">2007</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center"><span style="padding-left:3px;padding-right:3px;">롯데</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center"><span style="padding-left:3px;padding-right:3px;">22</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="statdata"><span style="padding-left:3px;padding-right:3px;">C</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">125</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">474</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">413</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">48</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">112</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">20</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">14</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">174</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">68</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">1</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">4</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">37</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">4</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">1</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">88</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">10</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">17</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">3</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;border-left:2px solid #333333;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.271</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.335</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.421</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.756</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.337</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">105.2</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;border-left:2px solid #333333;" class="statdata"><span style="padding-left:3px;padding-right:3px;">3.32</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;"></td></tr><tr><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="colhead_stz"><span style="padding-left:3px;padding-right:3px;">2008</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center"><span style="padding-left:3px;padding-right:3px;">롯데</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center"><span style="padding-left:3px;padding-right:3px;">23</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="statdata"><span style="padding-left:3px;padding-right:3px;">C</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">122</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">501</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">435</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">51</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">127</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">25</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">1</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">19</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">211</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">82</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">2</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">4</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">49</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">7</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">1</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">77</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">13</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">10</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;border-left:2px solid #333333;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.292</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.365</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.485</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.850</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.387</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">136.5</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;border-left:2px solid #333333;" class="statdata"><span style="padding-left:3px;padding-right:3px;">5.37</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;"></td></tr><tr><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="colhead_stz"><span style="padding-left:3px;padding-right:3px;">2009</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center"><span style="padding-left:3px;padding-right:3px;">롯데</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center"><span style="padding-left:3px;padding-right:3px;">24</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="statdata"><span style="padding-left:3px;padding-right:3px;">C</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">83</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">301</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">262</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">36</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">68</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">13</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">9</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">108</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">30</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">33</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">3</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">1</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">44</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">9</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">3</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;border-left:2px solid #333333;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.260</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.346</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.412</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.758</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">0.342</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">94.8</span></font></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;border-left:2px solid #333333;" class="statdata"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">1.80</span></font></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;"></td></tr><tr><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="colhead_stz"><span style="padding-left:3px;padding-right:3px;">2010</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center"><span style="padding-left:3px;padding-right:3px;">롯데</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center"><span style="padding-left:3px;padding-right:3px;">25</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="statdata"><span style="padding-left:3px;padding-right:3px;">C</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">117</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">465</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">410</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">66</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">125</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">19</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">1</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">23</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">215</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">72</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">2</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">7</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">42</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">8</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">1</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">65</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">16</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">5</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;border-left:2px solid #333333;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.305</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.376</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.524</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0
&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">비율</div></th><th rowspan="2" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;border-left:2px solid #333333;" onmouseover="ExpSet(&quot;대체 선수 대비 승리 기여 (수비 RAA 제외)&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">WAR*</div></th><th colspan="1" rowspan="2" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;"><span style="color:#999999;padding-left:3px;padding-right:3px;">WPA</span></th></tr><tr class="colhead_stz0"><th rowspan="1" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;border-left:2px solid #333333;" onmouseover="ExpSet(&quot;타율 (안타/타수)&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">타율</div></th><th rowspan="1" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;출루율 ((안타+볼넷+몸에맞는볼)/(타수+볼넷+몸에맞는볼+희생플라이))&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">출루</div></th><th rowspan="1" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;장타율 (총루타수/타수)&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">장타</div></th><th rowspan="1" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;OPS (출루율+장타율)&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">OPS</div></th><th rowspan="1" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;Weighted On Base Average,  (0.72*고4제외4구+0.75*사구+0.90*단타+0.92*실출+1.24*2타+1.56*3타+1.95*홈런)/(타석-고4), 출루율 스케일&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">wOBA</div></th><th rowspan="1" colspan="1" style="white-space:nowrap;vertical-align:middle;text-align:center;background:#DDDDDD;width:10px;text-align:center;" onmouseover="ExpSet(&quot;조정 wRC, (((파크팩터를_적용한_wRAA /타석)/(리그득점/리그타석))+1)*100, OPS+ 스케일&quot;)" onmouseout="ExpInit()"><div style="padding-left:3px;padding-right:3px;">wRC+</div></th></tr><tr class="oddrow_stz0"><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="colhead_stz"><span style="padding-left:3px;padding-right:3px;">18</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" colspan="2"><span style="padding-left:3px;padding-right:3px;">통산</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;" align="center" class="statdata"><span style="padding-left:3px;padding-right:3px;">C</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">1978</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">7318</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">6387</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">823</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">1761</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">317</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">10</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">290</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">2968</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">1022</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">23</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">32</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">678</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">145</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">41</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">1354</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">189</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">44</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">64</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;border-left:2px solid #333333;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.276</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.355</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.465</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.820</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">0.367</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;" class="statdata"><span style="padding-left:3px;padding-right:3px;">115.2</span></td><td style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;border-left:2px solid #333333;" class="statdata"><span style="padding-left:3px;padding-right:3px;">57.58</span></td><td style="white-space:nowrap;text-align:center;vertical-align:middle;"></td></tr>			</tbody></table>
	    </div>

# %%
col_tag = temp_table.find_all('td')
col_tag
# Out:
# [<td align="center" class="colhead_stz" style="white-space:nowrap;text-align:center;vertical-align:middle;"><span style="padding-left:3px;padding-right:3px;">2004</span></td>,
#  <td align="center" style="white-space:nowrap;text-align:center;vertical-align:middle;"><span style="padding-left:3px;padding-right:3px;">롯데</span></td>,
#  <td align="center" style="white-space:nowrap;text-align:center;vertical-align:middle;"><span style="padding-left:3px;padding-right:3px;">19</span></td>,
#  <td align="center" class="statdata" style="white-space:nowrap;text-align:center;vertical-align:middle;"><span style="padding-left:3px;padding-right:3px;">C</span></td>,
#  <td class="statdata" style="text-align:right;white-space:nowrap;text-align:center;vertical-align:middle;"><font color="#4B4B4B"><span style="padding-left:3px;padding-right:3px;">3</span></font></td>,
# ...

# %%
for col in col_tag:
    temp_value  = col.attrs['class']
    print(temp_value)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-5f069088dbdf> in <module>
#       1 for col in col_tag:
# ----> 2     temp_value  = col.attrs['statdata']
#       3     print(temp_value)
#
# KeyError: 'statdata'

# %%
    for col in col_tag:
        try:
            temp_value = col.attrs['data-id']
            if temp_value not in col_list:
                col_list.append(temp_value)
            else:
                break
        except:
            pass
    temp_data = pd.DataFrame(columns = col_list)

    i = 0
    index = 0
    col_len = len(col_list)
    while True:
        try:
            temp_data.loc[i] = [x.text for x in temp_table.find_all('td')[index:index + col_len]]
            i += 1
            index += col_len
        except:
            break
    
    data_list.append(temp_data)
